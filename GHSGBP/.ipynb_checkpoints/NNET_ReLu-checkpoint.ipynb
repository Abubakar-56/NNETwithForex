# %%
import pandas as pd 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error

# %%
# Imported Interbank FX Rates Historical.csv
Interbank_FX_Rates_Historical = pd.read_csv('./datasets/Interbank FX Rates Historical.csv')
# Deleted columns Currency, Currency Pair, Buying
Interbank_FX_Rates_Historical.drop(['Currency', 'Currency Pair', 'Buying','Mid Rate'], axis=1, inplace=True)
# Renamed columns GBPGHS
Interbank_FX_Rates_Historical.rename(columns={'Selling': 'GBPGHS'}, inplace=True)

# %%
# Imported Interbank FX Rates Historical (1).csv
Interbank_FX_Rates_Historical_1 = pd.read_csv('./datasets/Interbank FX Rates Historical (1).csv')
# Deleted columns Currency, Currency Pair, Buying
Interbank_FX_Rates_Historical_1.drop(['Currency', 'Currency Pair', 'Buying','Mid Rate'], axis=1, inplace=True)
# Renamed columns USDGHS
Interbank_FX_Rates_Historical_1.rename(columns={'Selling': 'USDGHS'}, inplace=True)

# %%
# Merged Interbank_FX_Rates_Historical_1 and Interbank_FX_Rates_Historical into df3
temp_df = Interbank_FX_Rates_Historical.drop_duplicates(subset=['Date']) # Remove duplicates so lookup merge only returns first match
df = Interbank_FX_Rates_Historical_1.merge(temp_df, left_on=['Date'], right_on=['Date'], how='left', suffixes=['_Interbank_FX_Rates_Historical_1', '_Interbank_FX_Rates_Historical'])
df.head()
# Out:
#           Date  USDGHS  GBPGHS
# 0  31 Dec 2020  7.8787  5.7631
# 1  30 Dec 2020  7.8087  5.7371
# 2  29 Dec 2020  7.7383  5.7351
# 3  24 Dec 2020  7.7779  5.7351
# 4  23 Dec 2020  7.7344  5.7241

# %%
# Check for missing values
print('missing values:', df.isnull().sum().sort_values(ascending = False))
# Out:
# missing values: Date      0
# USDGHS    0
# GBPGHS    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3226 entries, 0 to 3225
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3226 non-null   object
#  1   USDGHS  3226 non-null   object
#  2   GBPGHS  3226 non-null   object
# dtypes: object(3)
# memory usage: 100.8+ KB

# %%
df['USDGHS'] = pd.to_numeric(df['USDGHS'], errors='coerce')
df['GBPGHS'] = pd.to_numeric(df['GBPGHS'], errors='coerce')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
# Resample the DataFrame to a daily frequency and forward-fill missing values
df = df.resample('D').ffill()
df = df.fillna(method='bfill')
df.describe()
# Out:
#             USDGHS       GBPGHS
# count  4748.000000  4748.000000
# mean      4.320325     3.040635
# std       1.846412     1.547481
# min       0.000000     0.000000
# 25%       2.454700     1.522400
# 50%       4.878600     3.011850
# 75%       5.922800     4.404125
# max       7.878700     5.763100

# %%
df_plot = df.copy()
df.head()
# Out:
#             USDGHS  GBPGHS
# Date
# 2008-01-02  1.9427  0.9799
# 2008-01-03  1.9394  0.9799
# 2008-01-04  1.9309  0.9798
# 2008-01-05  1.9309  0.9798
# 2008-01-06  1.9309  0.9798

# %%
# Let's see a historical view of the closing Rate
df_plot['USDGHS'].plot(legend=True, figsize=(10,4))
df_plot['GBPGHS'].plot(legend=True, figsize=(10,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Let's go ahead and plot out several moving averages
MA_day = [10,50,200]

for ma in MA_day:
    column_name = 'MA for %s days' %(str(ma))
    df_plot[column_name] = df_plot['GBPGHS'].rolling(window=ma).mean()
df_plot = df_plot[['GBPGHS','MA for 10 days','MA for 50 days','MA for 200 days']].plot(subplots=False,figsize=(19,8))

# %%
GBPGHS = df['GBPGHS']
GBPGHS.to_csv('datasets/GBPGHS.csv')
GBPGHS.head()
# Out:
# Date
# 2008-01-02    0.9799
# 2008-01-03    0.9799
# 2008-01-04    0.9798
# 2008-01-05    0.9798
# 2008-01-06    0.9798
# Freq: D, Name: GBPGHS, dtype: float64

# %% [markdown]
# It is not necessary to check for autocorrelation in time series before using LSTM. However, it is important to check for autocorrelation in time series data before using any time series model. Autocorrelation is a measure of the correlation between the values of a time series at different points in time. If there is autocorrelation in the data, it means that the values of the time series at one point in time are correlated with the values at other points in time. This can lead to biased estimates of the model parameters and can affect the accuracy of the model predictions

# %%
from statsmodels.graphics import tsaplots
import matplotlib.pyplot as plt

#plot autocorrelation function
fig = tsaplots.plot_acf(df["USDGHS"], lags=12)
fig = tsaplots.plot_acf(df["GBPGHS"], lags=12)
plt.show()

# %%
print('the shape of the  dataset is ', GBPGHS.shape)
# Out:
# the shape of the  dataset is  (4748,)

# %% [markdown]
# ### Transforming the time series into well labelled training and testing dataset
#
# We will use the following function to transform time series into well labelled braining training and target samples. i.e we transform out input into a tuple (n_samples,n_timesteps,n_features)

# %%
def Model_data_setup(data, lookback, delay, min_index, max_index):
    """
    data:     Shape (n_samples, n_features). First column is the time series, other columns are the features.
              If there is only one column, it is assumed to be the time series data.
    lookback: Number of time steps in the Model >= 1
    delay:    The number of time steps to predict >= 1.
    min_index,max_index: The starting and ending indices of the time series portion to construct the data.
                         Allows constructing validation and test sets from the series in proper shape
    Returns: A tuple (x, y) of numpy arrays where x is in shape (n_samples, n_timesteps, n_features) and 
             y is in shape (n_samples, delay). y is an array of target arrays each of size delay. To forecast 
             a single value n timesteps ahead, set delay = n and take the last element of the forecast array.
    """
    if data.ndim == 1:
        data = np.expand_dims(data, axis=1)
    n_samples = max_index - lookback - delay + 1
    x_shape = (n_samples, lookback, data.shape[1])
    x = np.zeros(x_shape)
    y_shape = (n_samples, delay)
    y = np.zeros(y_shape)

    for i in range(n_samples):
        start_index = i + min_index
        end_index = start_index + lookback
        x[i,:,:] = data[start_index:end_index,:]
        y[i,:] = data[end_index + delay - 1, 0]

    return x, y

# %%
xdata, ydata = Model_data_setup(GBPGHS.values, lookback=5, delay=1, min_index=0, max_index=len(GBPGHS)-1)

# %% [markdown]
# ### Splitting the dataset into the training and testing sets
#
# We are splitting the dataset of normalized stock Rates into 80$\%$ and 20$\%$ for training and testing respectively. 20 $\%$ of training set will be assigned for validation at later stage.

# %%
#Specifying the sizes of training and testing datasets.
train_size = int(len(xdata)*0.6) # 2416#
valid_size = int(len(xdata)*0.2) #605#
test_size = len(xdata) - train_size-valid_size #355#

#Splitting the dataset into trainig, validation and testing.
xtrain, xvalid, xtest = xdata[0:train_size,:], xdata[train_size:train_size+valid_size,:], xdata[train_size+valid_size:len(xdata),:]
ytrain, yvalid, ytest = ydata[0:train_size,:], ydata[train_size:train_size+valid_size,:], ydata[train_size+valid_size:len(ydata),:]

print('The shape of the training sample is: ', xtrain.shape)
print('The shape of the validation sample is: ', xvalid.shape)
print('The shape of the testing sample is: ', xtest.shape)
print('The shape of the training target is: ', ytrain.shape)
print('The shape of the validation target is: ', yvalid.shape)
print('The shape of the testing target is: ', ytest.shape)
# Out:
# The shape of the training sample is:  (2845, 5, 1)
# The shape of the validation sample is:  (948, 5, 1)
# The shape of the testing sample is:  (949, 5, 1)
# The shape of the training target is:  (2845, 1)
# The shape of the validation target is:  (948, 1)
# The shape of the testing target is:  (949, 1)

# %%
xtrain = np.reshape(xtrain, (xtrain.shape[0], xtrain.shape[1], -1))
xvalid = np.reshape(xvalid, (xvalid.shape[0], xvalid.shape[1], -1))
xtest = np.reshape(xtest, (xtest.shape[0], xtest.shape[1], -1))
xtrain.shape,xvalid.shape,xtest.shape
# Out:
# ((2845, 5, 1), (948, 5, 1), (949, 5, 1))

# %% [markdown]
# ## Neural Networks Models

# %%
from keras.models import Sequential
from keras.models import Model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, SimpleRNN, LSTM,GRU,Conv1D, ConvLSTM2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Reshape
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# The RNNs have a feedback mechanism that allows them to take into account the previous inputs in the sequence while making predictions. This feedback loop creates a kind of memory within the network, which is why RNNs are well-suited for sequential data. The mathematical representation of an RNN is:
#
# \begin{equation}
# h_t = f(W_{hh}h_{t-1} + W_{xh}x_t + b_h)
# \end{equation}
#
# where $h_t$ is the hidden state at time $t$, $x_t$ is the input at time $t$, $W_{hh}$ is the weight matrix for the hidden-to-hidden connections, $W_{xh}$ is the weight matrix for the input-to-hidden connections, $b_h$ is the bias term, and $f$ is an activation function.

# %% [markdown]
# LSTM networks are a type of RNN that are designed to address the vanishing gradient problem that can occur in traditional RNNs. LSTM networks use memory cells and gates to selectively remember or forget information from previous inputs. The mathematical representation of an LSTM network is:
#
# \begin{align}
# f_t &= \sigma(W_f \cdot [h_{t-1}, x_t] + b_f) \\
# i_t &= \sigma(W_i \cdot [h_{t-1}, x_t] + b_i) \\
# o_t &= \sigma(W_o \cdot [h_{t-1}, x_t] + b_o) \\
# \tilde{C}t &= \tanh(W_C \cdot [h{t-1}, x_t] + b_C) \\
# C_t &= f_t * C_{t-1} + i_t * \tilde{C}_t \\
# h_t &= o_t * \tanh(C_t)
# \end{align}
#
# where $f_t$ is the forget gate, $i_t$ is the input gate, $o_t$ is the output gate, $\tilde{C}_t$ is the candidate cell state, $C_t$ is the cell state, and $h_t$ is the hidden state. $W_f$, $W_i$, $W_o$, and $W_C$ are the weight matrices, and $b_f$, $b_i$, $b_o$, and $b_C$ are the bias terms. $\sigma$ is the sigmoid activation function, and $\tanh$ is the hyperbolic tangent activation function.

# %% [markdown]
# Let's consider a sequence of two-dimensional data, represented as a tensor $X$ of shape $(num_timesteps, height, width, channels)$. At each time step $t$, the input $X[t]$ is processed by a ConvLSTM cell, which consists of several operations.
#
# First, the cell applies a convolution operation to the input $X[t]$ and the previous hidden state $H[t-1]$, with a set of filters $W_x$ and $W_h$, respectively. The output of this convolution is a set of feature maps $F[t]$:
#
# $$F[t] = \text{Conv}(X[t], W_x) + \text{Conv}(H[t-1], W_h)$$
#
# Next, the cell applies several gating mechanisms to control the flow of information through the network. Specifically, it computes three gates: the input gate $i[t]$, the forget gate $f[t]$, and the output gate $o[t]$:
#
# \begin{align*}
# i[t] &= \sigma(\text{Conv}(X[t], W_i) + \text{Conv}(H[t-1], U_i)) \\
# f[t] &= \sigma(\text{Conv}(X[t], W_f) + \text{Conv}(H[t-1], U_f)) \\
# o[t] &= \sigma(\text{Conv}(X[t], W_o) + \text{Conv}(H[t-1], U_o))
# \end{align*}
#
# where $\sigma$ represents the sigmoid activation function, and $W_i$, $W_f$, $W_o$, $U_i$, $U_f$, and $U_o$ are the weights for the convolutional filters used to compute each gate.
#
# These gates control which information is passed through the cell, and which information is discarded. The input gate $i[t]$ determines how much of the new input $F[t]$ is added to the memory cell $C[t]$, which stores the current state of the cell:
#
# $$C[t] = i[t] \cdot \tanh(\text{Conv}(X[t], W_c) + \text{Conv}(H[t-1], U_c)) + f[t] \cdot C[t-1]$$
#
# where $\tanh$ represents the hyperbolic tangent activation function, and $W_c$ and $U_c$ are the weights for the convolutional filters used to compute the cell state.
#
# Finally, the output gate $o[t]$ determines the output of the cell:
#
# $$H[t] = o[t] \cdot \tanh(C[t])$$
#
# where $H[t]$ is the output of the cell at time ste

# %%
n_features = GBPGHS.shape
lr = 0.0016#Learning rate
units = 16 #Number hidden units
batch_size=64
lookback = 5
delay = 1
min_index = 0
max_index = GBPGHS.shape[0] - 1

# Define the number of features in the input data
n_features = 1  # We only have one feature, which is the GBPGHS exchange rate

# Convert the data into the required format for the model
xdata, ydata = Model_data_setup(GBPGHS.values.reshape(-1, 1), lookback, delay, min_index, max_index)

# %% [markdown]
# RNN model using the Sequential class from the `tf.keras.models` module. The model consists of three layers: an input layer, a SimpleRNN layer, and a Dense layer.
#
# The Input layer specifies the shape of the input data, which is a 3D tensor with shape `(n_timesteps, n_features)` where `n_timesteps` is the number of time steps in each input sequence and n_features is the number of features in each time step.
#
# The SimpleRNN layer is a type of RNN layer that uses the recurrent activation function tanh by default. It has 64 units and uses the `relu` activation function. This layer takes the input sequences as input and outputs a sequence of hidden states.
#
# The Dense layer is a fully connected layer that takes the last hidden state from the SimpleRNN layer and outputs a single value, which is the predicted value for the next time step.

# %%
# Define RNN model
RNN = Sequential()
RNN.add(SimpleRNN(units, activation='relu', input_shape=(lookback, n_features), return_sequences=False, recurrent_dropout=0.3))
RNN.add(Dense(5))
RNN.add(Reshape((5, 1)))

RNN.compile(optimizer='Adam', loss='mse', metrics=['mae'])
RNN.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 16)                288
#
#  dense_10 (Dense)            (None, 5)                 85
#
#  reshape_4 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________

# %%
LSTM_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    LSTM(32, activation='relu', return_sequences=True),
    LSTM(32, activation='relu'),
    Dense(5),
    Reshape((5, 1))
])

LSTM_Model.compile(loss='mse', optimizer='Adam' , metrics=["mae"])
LSTM_Model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 5, 32)             4352
#
#  lstm_13 (LSTM)              (None, 32)                8320
#
#  dense_26 (Dense)            (None, 5)                 165
#
#  reshape_8 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 12,837
# Trainable params: 12,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define GRU model
GRU_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    GRU(128, return_sequences=True),
    Dense(5),
    Dense(1)
])

GRU_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
GRU_Model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_6 (GRU)                 (None, 5, 128)            50304
#
#  dense_27 (Dense)            (None, 5, 5)              645
#
#  dense_28 (Dense)            (None, 5, 1)              6
#
# =================================================================
# Total params: 50,955
# Trainable params: 50,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define MLP model
MLP_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(5)
    # Reshape((5,1))
])

MLP_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
MLP_Model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 5)                 0
#
#  dense_4 (Dense)             (None, 64)                384
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 2,629
# Trainable params: 2,629
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define Conv1D model
conv1D_Model = tf.keras.models.Sequential([
    Input(shape=(lookback, n_features)),
    Conv1D(32, kernel_size=3, activation='relu'),
    Flatten(),
    Dense(5, activation='relu'),
    Reshape((5,1))
])

conv1D_Model.compile(optimizer = 'Adam', loss='mse', metrics=["mae"])
conv1D_Model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 3, 32)             128
#
#  flatten_3 (Flatten)         (None, 96)                0
#
#  dense_9 (Dense)             (None, 5)                 485
#
#  reshape_3 (Reshape)         (None, 5, 1)              0
#
# =================================================================
# Total params: 613
# Trainable params: 613
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Fitting All The Models

# %%
np.random.seed(123)
history_1=RNN.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=100, verbose=1)
RNN_df = pd.DataFrame(history_1.history)
RNN_df.tail()
# Out:
# Epoch 1/100
# 89/89 [==============================] - 3s 9ms/step - loss: 3.8835 - mae: 1.4796 - val_loss: 3.2301 - val_mae: 1.5151
# Epoch 2/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.8648 - mae: 0.6819 - val_loss: 1.1995 - val_mae: 0.9658
# Epoch 3/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.5161 - mae: 0.5240 - val_loss: 0.7613 - val_mae: 0.8053
# Epoch 4/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.3552 - mae: 0.4146 - val_loss: 0.5093 - val_mae: 0.6600
# Epoch 5/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.2589 - mae: 0.3524 - val_loss: 0.4159 - val_mae: 0.6160
# Epoch 6/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.1818 - mae: 0.2935 - val_loss: 0.3785 - val_mae: 0.5892
# Epoch 7/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.1445 - mae: 0.2564 - val_loss: 0.3242 - val_mae: 0.5389
# Epoch 8/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.1117 - mae: 0.2222 - val_loss: 0.2814 - val_mae: 0.4996
# Epoch 9/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0896 - mae: 0.1969 - val_loss: 0.2104 - val_mae: 0.4176
# Epoch 10/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0811 - mae: 0.1837 - val_loss: 0.1912 - val_mae: 0.3980
# Epoch 11/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0634 - mae: 0.1628 - val_loss: 0.1679 - val_mae: 0.3644
# Epoch 12/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0556 - mae: 0.1496 - val_loss: 0.1444 - val_mae: 0.3331
# Epoch 13/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0468 - mae: 0.1344 - val_loss: 0.1503 - val_mae: 0.3392
# Epoch 14/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0422 - mae: 0.1255 - val_loss: 0.1061 - val_mae: 0.2768
# Epoch 15/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0377 - mae: 0.1145 - val_loss: 0.1118 - val_mae: 0.2864
# Epoch 16/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0323 - mae: 0.1025 - val_loss: 0.0901 - val_mae: 0.2503
# Epoch 17/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0283 - mae: 0.0933 - val_loss: 0.0637 - val_mae: 0.1984
# Epoch 18/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0252 - mae: 0.0858 - val_loss: 0.0620 - val_mae: 0.1885
# Epoch 19/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0230 - mae: 0.0788 - val_loss: 0.0579 - val_mae: 0.1769
# Epoch 20/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0221 - mae: 0.0748 - val_loss: 0.0481 - val_mae: 0.1566
# Epoch 21/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0193 - mae: 0.0675 - val_loss: 0.0433 - val_mae: 0.1444
# Epoch 22/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0185 - mae: 0.0647 - val_loss: 0.0349 - val_mae: 0.1271
# Epoch 23/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0174 - mae: 0.0600 - val_loss: 0.0305 - val_mae: 0.1147
# Epoch 24/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0158 - mae: 0.0558 - val_loss: 0.0231 - val_mae: 0.0998
# Epoch 25/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0155 - mae: 0.0532 - val_loss: 0.0224 - val_mae: 0.1021
# Epoch 26/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0148 - mae: 0.0513 - val_loss: 0.0209 - val_mae: 0.0993
# Epoch 27/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0141 - mae: 0.0489 - val_loss: 0.0153 - val_mae: 0.0740
# Epoch 28/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0139 - mae: 0.0463 - val_loss: 0.0117 - val_mae: 0.0616
# Epoch 29/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0141 - mae: 0.0454 - val_loss: 0.0099 - val_mae: 0.0598
# Epoch 30/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0133 - mae: 0.0427 - val_loss: 0.0086 - val_mae: 0.0602
# Epoch 31/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0133 - mae: 0.0414 - val_loss: 0.0059 - val_mae: 0.0500
# Epoch 32/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0125 - mae: 0.0397 - val_loss: 0.0052 - val_mae: 0.0473
# Epoch 33/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0125 - mae: 0.0386 - val_loss: 0.0046 - val_mae: 0.0505
# Epoch 34/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0120 - mae: 0.0371 - val_loss: 0.0045 - val_mae: 0.0466
# Epoch 35/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0116 - mae: 0.0355 - val_loss: 0.0032 - val_mae: 0.0416
# Epoch 36/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0124 - mae: 0.0352 - val_loss: 0.0025 - val_mae: 0.0386
# Epoch 37/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0115 - mae: 0.0335 - val_loss: 0.0023 - val_mae: 0.0351
# Epoch 38/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0111 - mae: 0.0331 - val_loss: 0.0017 - val_mae: 0.0324
# Epoch 39/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0108 - mae: 0.0318 - val_loss: 0.0019 - val_mae: 0.0347
# Epoch 40/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0109 - mae: 0.0320 - val_loss: 0.0015 - val_mae: 0.0321
# Epoch 41/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0109 - mae: 0.0307 - val_loss: 0.0011 - val_mae: 0.0264
# Epoch 42/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0104 - mae: 0.0296 - val_loss: 0.0012 - val_mae: 0.0281
# Epoch 43/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0104 - mae: 0.0284 - val_loss: 0.0010 - val_mae: 0.0252
# Epoch 44/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0276 - val_loss: 9.9383e-04 - val_mae: 0.0254
# Epoch 45/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0270 - val_loss: 8.0250e-04 - val_mae: 0.0229
# Epoch 46/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0091 - mae: 0.0258 - val_loss: 9.1978e-04 - val_mae: 0.0243
# Epoch 47/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0105 - mae: 0.0256 - val_loss: 5.4136e-04 - val_mae: 0.0204
# Epoch 48/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0249 - val_loss: 4.5832e-04 - val_mae: 0.0167
# Epoch 49/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0099 - mae: 0.0245 - val_loss: 6.9340e-04 - val_mae: 0.0219
# Epoch 50/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0229 - val_loss: 5.6172e-04 - val_mae: 0.0203
# Epoch 51/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0091 - mae: 0.0227 - val_loss: 1.9020e-04 - val_mae: 0.0107
# Epoch 52/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0094 - mae: 0.0212 - val_loss: 4.3002e-04 - val_mae: 0.0173
# Epoch 53/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0213 - val_loss: 2.3865e-04 - val_mae: 0.0124
# Epoch 54/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0088 - mae: 0.0201 - val_loss: 2.2960e-04 - val_mae: 0.0123
# Epoch 55/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0203 - val_loss: 2.7876e-04 - val_mae: 0.0127
# Epoch 56/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0094 - mae: 0.0195 - val_loss: 6.9594e-04 - val_mae: 0.0250
# Epoch 57/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0216 - val_loss: 0.0011 - val_mae: 0.0311
# Epoch 58/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0202 - val_loss: 4.1711e-04 - val_mae: 0.0169
# Epoch 59/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0091 - mae: 0.0191 - val_loss: 1.5110e-04 - val_mae: 0.0092
# Epoch 60/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0092 - mae: 0.0190 - val_loss: 2.3228e-04 - val_mae: 0.0130
# Epoch 61/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0090 - mae: 0.0188 - val_loss: 1.9547e-04 - val_mae: 0.0121
# Epoch 62/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0086 - mae: 0.0189 - val_loss: 4.2024e-04 - val_mae: 0.0189
# Epoch 63/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0104 - mae: 0.0199 - val_loss: 9.6694e-05 - val_mae: 0.0063
# Epoch 64/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0093 - mae: 0.0193 - val_loss: 7.3568e-05 - val_mae: 0.0050
# Epoch 65/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0090 - mae: 0.0189 - val_loss: 7.4851e-05 - val_mae: 0.0045
# Epoch 66/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0100 - mae: 0.0195 - val_loss: 8.0573e-05 - val_mae: 0.0057
# Epoch 67/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0096 - mae: 0.0183 - val_loss: 8.8596e-05 - val_mae: 0.0057
# Epoch 68/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0106 - mae: 0.0178 - val_loss: 7.8078e-05 - val_mae: 0.0055
# Epoch 69/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0097 - mae: 0.0195 - val_loss: 8.4335e-05 - val_mae: 0.0059
# Epoch 70/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0096 - mae: 0.0177 - val_loss: 2.8323e-04 - val_mae: 0.0154
# Epoch 71/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0087 - mae: 0.0164 - val_loss: 2.0820e-04 - val_mae: 0.0125
# Epoch 72/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0090 - mae: 0.0172 - val_loss: 2.3533e-04 - val_mae: 0.0137
# Epoch 73/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0093 - mae: 0.0183 - val_loss: 2.9906e-04 - val_mae: 0.0158
# Epoch 74/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0086 - mae: 0.0180 - val_loss: 3.2807e-04 - val_mae: 0.0167
# Epoch 75/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0089 - mae: 0.0168 - val_loss: 6.5100e-05 - val_mae: 0.0038
# Epoch 76/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0095 - mae: 0.0189 - val_loss: 5.0773e-04 - val_mae: 0.0211
# Epoch 77/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0087 - mae: 0.0176 - val_loss: 1.1904e-04 - val_mae: 0.0086
# Epoch 78/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0094 - mae: 0.0192 - val_loss: 6.1828e-05 - val_mae: 0.0034
# Epoch 79/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0085 - mae: 0.0170 - val_loss: 7.3053e-05 - val_mae: 0.0050
# Epoch 80/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0091 - mae: 0.0182 - val_loss: 1.1612e-04 - val_mae: 0.0079
# Epoch 81/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0094 - mae: 0.0189 - val_loss: 2.4198e-04 - val_mae: 0.0140
# Epoch 82/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0084 - mae: 0.0166 - val_loss: 1.1939e-04 - val_mae: 0.0086
# Epoch 83/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0089 - mae: 0.0177 - val_loss: 8.3298e-04 - val_mae: 0.0280
# Epoch 84/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0089 - mae: 0.0204 - val_loss: 9.4791e-05 - val_mae: 0.0070
# Epoch 85/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0094 - mae: 0.0181 - val_loss: 2.2953e-04 - val_mae: 0.0135
# Epoch 86/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0090 - mae: 0.0171 - val_loss: 2.3299e-04 - val_mae: 0.0137
# Epoch 87/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0090 - mae: 0.0170 - val_loss: 1.5551e-04 - val_mae: 0.0105
# Epoch 88/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0085 - mae: 0.0173 - val_loss: 6.7478e-05 - val_mae: 0.0042
# Epoch 89/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0091 - mae: 0.0175 - val_loss: 6.5640e-05 - val_mae: 0.0040
# Epoch 90/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0085 - mae: 0.0162 - val_loss: 2.3012e-04 - val_mae: 0.0136
# Epoch 91/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0094 - mae: 0.0188 - val_loss: 1.4329e-04 - val_mae: 0.0098
# Epoch 92/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0087 - mae: 0.0184 - val_loss: 2.8823e-04 - val_mae: 0.0155
# Epoch 93/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0093 - mae: 0.0170 - val_loss: 2.7741e-04 - val_mae: 0.0153
# Epoch 94/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0095 - mae: 0.0171 - val_loss: 9.9115e-05 - val_mae: 0.0071
# Epoch 95/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0096 - mae: 0.0173 - val_loss: 7.7539e-04 - val_mae: 0.0267
# Epoch 96/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0177 - val_loss: 0.0022 - val_mae: 0.0463
# Epoch 97/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0088 - mae: 0.0188 - val_loss: 7.3946e-05 - val_mae: 0.0051
# Epoch 98/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0089 - mae: 0.0167 - val_loss: 8.4397e-05 - val_mae: 0.0059
# Epoch 99/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0085 - mae: 0.0165 - val_loss: 4.0739e-04 - val_mae: 0.0188
# Epoch 100/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0091 - mae: 0.0171 - val_loss: 6.0398e-05 - val_mae: 0.0033

# %%
# print('')
# plt.figure(figsize=(9,5))
# plt.plot(RNN_df['loss'], label ='Training loss (MSE)', color = 'blue')
# plt.plot(RNN_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
# plt.xlabel('Mini-batch', fontsize=13)
# plt.ylabel('Loss', fontsize=13)
# plt.legend(fontsize=13)
# plt.savefig('images/RNN_error1.eps', format='eps', dpi=1000)
# plt.show()

# %%
np.random.seed(123)
history_2=LSTM_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=100, verbose=1)
LSTM_df = pd.DataFrame(history_2.history)
# Out:
# Epoch 1/100
# 89/89 [==============================] - 4s 11ms/step - loss: 2.1837 - mae: 1.1843 - val_loss: 0.5243 - val_mae: 0.6638
# Epoch 2/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0329 - mae: 0.1081 - val_loss: 0.0311 - val_mae: 0.1568
# Epoch 3/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0191 - mae: 0.0673 - val_loss: 0.0306 - val_mae: 0.1619
# Epoch 4/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0169 - mae: 0.0579 - val_loss: 0.0345 - val_mae: 0.1798
# Epoch 5/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0142 - mae: 0.0392 - val_loss: 0.0011 - val_mae: 0.0262
# Epoch 6/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0135 - mae: 0.0388 - val_loss: 0.0062 - val_mae: 0.0725
# Epoch 7/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0126 - mae: 0.0302 - val_loss: 0.0018 - val_mae: 0.0347
# Epoch 8/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0129 - mae: 0.0363 - val_loss: 0.0010 - val_mae: 0.0239
# Epoch 9/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0124 - mae: 0.0318 - val_loss: 0.0015 - val_mae: 0.0323
# Epoch 10/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0123 - mae: 0.0320 - val_loss: 0.0026 - val_mae: 0.0466
# Epoch 11/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0124 - mae: 0.0334 - val_loss: 0.0018 - val_mae: 0.0368
# Epoch 12/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0124 - mae: 0.0345 - val_loss: 7.1555e-04 - val_mae: 0.0188
# Epoch 13/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0121 - mae: 0.0310 - val_loss: 0.0139 - val_mae: 0.1157
# Epoch 14/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0121 - mae: 0.0311 - val_loss: 0.0022 - val_mae: 0.0422
# Epoch 15/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0118 - mae: 0.0286 - val_loss: 7.5457e-04 - val_mae: 0.0212
# Epoch 16/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0123 - mae: 0.0349 - val_loss: 5.1214e-04 - val_mae: 0.0154
# Epoch 17/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0118 - mae: 0.0304 - val_loss: 0.0037 - val_mae: 0.0575
# Epoch 18/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0117 - mae: 0.0299 - val_loss: 0.0195 - val_mae: 0.1379
# Epoch 19/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0121 - mae: 0.0381 - val_loss: 0.0010 - val_mae: 0.0272
# Epoch 20/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0115 - mae: 0.0311 - val_loss: 0.0012 - val_mae: 0.0304
# Epoch 21/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0121 - mae: 0.0386 - val_loss: 4.9530e-04 - val_mae: 0.0141
# Epoch 22/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0113 - mae: 0.0294 - val_loss: 0.0050 - val_mae: 0.0680
# Epoch 23/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0113 - mae: 0.0302 - val_loss: 6.4316e-04 - val_mae: 0.0191
# Epoch 24/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0110 - mae: 0.0276 - val_loss: 6.3308e-04 - val_mae: 0.0191
# Epoch 25/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0111 - mae: 0.0323 - val_loss: 0.0170 - val_mae: 0.1284
# Epoch 26/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0114 - mae: 0.0357 - val_loss: 0.0037 - val_mae: 0.0572
# Epoch 27/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0114 - mae: 0.0358 - val_loss: 6.0102e-04 - val_mae: 0.0185
# Epoch 28/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0107 - mae: 0.0280 - val_loss: 0.0012 - val_mae: 0.0274
# Epoch 29/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0107 - mae: 0.0294 - val_loss: 0.0013 - val_mae: 0.0314
# Epoch 30/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0113 - mae: 0.0349 - val_loss: 0.0011 - val_mae: 0.0282
# Epoch 31/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0111 - mae: 0.0328 - val_loss: 7.5084e-04 - val_mae: 0.0205
# Epoch 32/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0106 - mae: 0.0315 - val_loss: 0.0052 - val_mae: 0.0682
# Epoch 33/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0111 - mae: 0.0364 - val_loss: 0.0014 - val_mae: 0.0311
# Epoch 34/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0105 - mae: 0.0280 - val_loss: 0.0015 - val_mae: 0.0322
# Epoch 35/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0109 - mae: 0.0310 - val_loss: 0.0018 - val_mae: 0.0371
# Epoch 36/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0109 - mae: 0.0359 - val_loss: 0.0034 - val_mae: 0.0545
# Epoch 37/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0110 - mae: 0.0369 - val_loss: 8.1864e-04 - val_mae: 0.0212
# Epoch 38/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0104 - mae: 0.0294 - val_loss: 0.0066 - val_mae: 0.0778
# Epoch 39/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0104 - mae: 0.0318 - val_loss: 9.2702e-04 - val_mae: 0.0262
# Epoch 40/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0101 - mae: 0.0275 - val_loss: 0.0080 - val_mae: 0.0864
# Epoch 41/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0102 - mae: 0.0279 - val_loss: 0.0077 - val_mae: 0.0847
# Epoch 42/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0282 - val_loss: 0.0138 - val_mae: 0.1147
# Epoch 43/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0102 - mae: 0.0292 - val_loss: 4.0814e-04 - val_mae: 0.0154
# Epoch 44/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0104 - mae: 0.0325 - val_loss: 4.8231e-04 - val_mae: 0.0168
# Epoch 45/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0104 - mae: 0.0340 - val_loss: 0.0021 - val_mae: 0.0421
# Epoch 46/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0106 - mae: 0.0359 - val_loss: 0.0098 - val_mae: 0.0960
# Epoch 47/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0101 - mae: 0.0304 - val_loss: 6.9724e-04 - val_mae: 0.0211
# Epoch 48/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0102 - mae: 0.0306 - val_loss: 4.8015e-04 - val_mae: 0.0165
# Epoch 49/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0098 - mae: 0.0258 - val_loss: 0.0031 - val_mae: 0.0517
# Epoch 50/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0099 - mae: 0.0282 - val_loss: 0.0026 - val_mae: 0.0478
# Epoch 51/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0295 - val_loss: 0.0083 - val_mae: 0.0883
# Epoch 52/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0103 - mae: 0.0313 - val_loss: 3.7516e-04 - val_mae: 0.0138
# Epoch 53/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0292 - val_loss: 0.0018 - val_mae: 0.0385
# Epoch 54/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0098 - mae: 0.0281 - val_loss: 0.0037 - val_mae: 0.0576
# Epoch 55/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0273 - val_loss: 0.0014 - val_mae: 0.0328
# Epoch 56/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0099 - mae: 0.0275 - val_loss: 0.0034 - val_mae: 0.0560
# Epoch 57/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0260 - val_loss: 9.6285e-04 - val_mae: 0.0253
# Epoch 58/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0098 - mae: 0.0277 - val_loss: 0.0108 - val_mae: 0.1020
# Epoch 59/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0101 - mae: 0.0327 - val_loss: 0.0010 - val_mae: 0.0266
# Epoch 60/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0101 - mae: 0.0327 - val_loss: 3.4018e-04 - val_mae: 0.0136
# Epoch 61/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0096 - mae: 0.0263 - val_loss: 5.5706e-04 - val_mae: 0.0187
# Epoch 62/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0102 - mae: 0.0360 - val_loss: 7.0801e-04 - val_mae: 0.0225
# Epoch 63/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0099 - mae: 0.0280 - val_loss: 0.0041 - val_mae: 0.0618
# Epoch 64/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0278 - val_loss: 0.0055 - val_mae: 0.0716
# Epoch 65/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0098 - mae: 0.0278 - val_loss: 0.0025 - val_mae: 0.0471
# Epoch 66/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0263 - val_loss: 0.0013 - val_mae: 0.0319
# Epoch 67/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0096 - mae: 0.0285 - val_loss: 4.0169e-04 - val_mae: 0.0154
# Epoch 68/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0096 - mae: 0.0289 - val_loss: 0.0030 - val_mae: 0.0530
# Epoch 69/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0271 - val_loss: 0.0032 - val_mae: 0.0538
# Epoch 70/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0098 - mae: 0.0293 - val_loss: 6.2388e-04 - val_mae: 0.0182
# Epoch 71/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0095 - mae: 0.0260 - val_loss: 0.0021 - val_mae: 0.0407
# Epoch 72/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0263 - val_loss: 0.0022 - val_mae: 0.0443
# Epoch 73/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0096 - mae: 0.0261 - val_loss: 0.0018 - val_mae: 0.0397
# Epoch 74/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0093 - mae: 0.0242 - val_loss: 0.0050 - val_mae: 0.0692
# Epoch 75/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0094 - mae: 0.0279 - val_loss: 8.1913e-04 - val_mae: 0.0249
# Epoch 76/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0100 - mae: 0.0320 - val_loss: 9.7683e-04 - val_mae: 0.0285
# Epoch 77/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0283 - val_loss: 0.0091 - val_mae: 0.0932
# Epoch 78/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0098 - mae: 0.0283 - val_loss: 0.0054 - val_mae: 0.0719
# Epoch 79/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0094 - mae: 0.0253 - val_loss: 9.6215e-04 - val_mae: 0.0276
# Epoch 80/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0098 - mae: 0.0319 - val_loss: 4.5626e-04 - val_mae: 0.0163
# Epoch 81/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0094 - mae: 0.0243 - val_loss: 4.9728e-04 - val_mae: 0.0175
# Epoch 82/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0093 - mae: 0.0238 - val_loss: 0.0021 - val_mae: 0.0407
# Epoch 83/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0261 - val_loss: 2.2123e-04 - val_mae: 0.0112
# Epoch 84/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0095 - mae: 0.0260 - val_loss: 2.1336e-04 - val_mae: 0.0110
# Epoch 85/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0092 - mae: 0.0244 - val_loss: 3.2218e-04 - val_mae: 0.0142
# Epoch 86/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0094 - mae: 0.0274 - val_loss: 2.8690e-04 - val_mae: 0.0132
# Epoch 87/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0303 - val_loss: 4.6853e-04 - val_mae: 0.0169
# Epoch 88/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0095 - mae: 0.0285 - val_loss: 4.4395e-04 - val_mae: 0.0183
# Epoch 89/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0092 - mae: 0.0238 - val_loss: 1.9763e-04 - val_mae: 0.0103
# Epoch 90/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0092 - mae: 0.0248 - val_loss: 5.8470e-04 - val_mae: 0.0185
# Epoch 91/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0093 - mae: 0.0259 - val_loss: 7.3467e-04 - val_mae: 0.0224
# Epoch 92/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0090 - mae: 0.0207 - val_loss: 0.0060 - val_mae: 0.0755
# Epoch 93/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0093 - mae: 0.0263 - val_loss: 2.5740e-04 - val_mae: 0.0123
# Epoch 94/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0094 - mae: 0.0268 - val_loss: 0.0020 - val_mae: 0.0405
# Epoch 95/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0097 - mae: 0.0286 - val_loss: 0.0012 - val_mae: 0.0286
# Epoch 96/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0092 - mae: 0.0237 - val_loss: 0.0035 - val_mae: 0.0570
# Epoch 97/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0093 - mae: 0.0258 - val_loss: 0.0055 - val_mae: 0.0719
# Epoch 98/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0097 - mae: 0.0317 - val_loss: 0.0070 - val_mae: 0.0817
# Epoch 99/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0094 - mae: 0.0300 - val_loss: 9.0238e-04 - val_mae: 0.0268
# Epoch 100/100
# 89/89 [==============================] - 1s 6ms/step - loss: 0.0091 - mae: 0.0239 - val_loss: 0.0031 - val_mae: 0.0549
#         loss       mae  val_loss   val_mae
# 95  0.009153  0.023669  0.003466  0.057032
# 96  0.009289  0.025806  0.005522  0.071923
# 97  0.009699  0.031702  0.006969  0.081741
# 98  0.009432  0.029967  0.000902  0.026830
# 99  0.009087  0.023949  0.003149  0.054921

# %%
# print('')
# plt.figure(figsize=(9,5))
# plt.plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
# plt.plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
# plt.xlabel('Mini-batch', fontsize=13)
# plt.ylabel('Loss', fontsize=13)
# plt.legend(fontsize=13)
# plt.savefig('images/LSTM_error1.png', format='png', dpi=1000)
# plt.show()

# %%
np.random.seed(123)
history_3=GRU_Model.fit(xtrain,ytrain, validation_data=(xvalid,yvalid), epochs=100, verbose=1)
GRU_df =pd.DataFrame(history_3.history)
GRU_df.tail()
# Out:
# Epoch 1/100
# 89/89 [==============================] - 4s 14ms/step - loss: 0.5231 - mae: 0.4624 - val_loss: 0.3468 - val_mae: 0.3955
# Epoch 2/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0422 - mae: 0.1076 - val_loss: 0.0367 - val_mae: 0.1415
# Epoch 3/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0219 - mae: 0.0550 - val_loss: 0.0162 - val_mae: 0.0940
# Epoch 4/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0204 - mae: 0.0443 - val_loss: 0.0094 - val_mae: 0.0684
# Epoch 5/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0197 - mae: 0.0390 - val_loss: 0.0040 - val_mae: 0.0358
# Epoch 6/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0193 - mae: 0.0374 - val_loss: 0.0041 - val_mae: 0.0430
# Epoch 7/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0191 - mae: 0.0378 - val_loss: 0.0040 - val_mae: 0.0605
# Epoch 8/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0188 - mae: 0.0351 - val_loss: 0.0057 - val_mae: 0.0724
# Epoch 9/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0186 - mae: 0.0350 - val_loss: 0.0023 - val_mae: 0.0447
# Epoch 10/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0184 - mae: 0.0326 - val_loss: 9.1640e-04 - val_mae: 0.0239
# Epoch 11/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0185 - mae: 0.0362 - val_loss: 0.0012 - val_mae: 0.0283
# Epoch 12/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0181 - mae: 0.0328 - val_loss: 0.0020 - val_mae: 0.0408
# Epoch 13/100
# 89/89 [==============================] - 1s 10ms/step - loss: 0.0183 - mae: 0.0374 - val_loss: 0.0031 - val_mae: 0.0493
# Epoch 14/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0180 - mae: 0.0365 - val_loss: 4.4665e-04 - val_mae: 0.0138
# Epoch 15/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0177 - mae: 0.0329 - val_loss: 0.0023 - val_mae: 0.0436
# Epoch 16/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0182 - mae: 0.0388 - val_loss: 0.0039 - val_mae: 0.0556
# Epoch 17/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0181 - mae: 0.0406 - val_loss: 8.6032e-04 - val_mae: 0.0238
# Epoch 18/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0177 - mae: 0.0379 - val_loss: 7.1259e-04 - val_mae: 0.0198
# Epoch 19/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0175 - mae: 0.0342 - val_loss: 0.0016 - val_mae: 0.0356
# Epoch 20/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0174 - mae: 0.0339 - val_loss: 0.0013 - val_mae: 0.0309
# Epoch 21/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0175 - mae: 0.0389 - val_loss: 0.0011 - val_mae: 0.0274
# Epoch 22/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0174 - mae: 0.0383 - val_loss: 4.6503e-04 - val_mae: 0.0131
# Epoch 23/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0172 - mae: 0.0365 - val_loss: 7.5287e-04 - val_mae: 0.0210
# Epoch 24/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0174 - mae: 0.0387 - val_loss: 0.0013 - val_mae: 0.0257
# Epoch 25/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0172 - mae: 0.0387 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 26/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0169 - mae: 0.0351 - val_loss: 0.0012 - val_mae: 0.0295
# Epoch 27/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0169 - mae: 0.0367 - val_loss: 0.0062 - val_mae: 0.0754
# Epoch 28/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0167 - mae: 0.0344 - val_loss: 0.0025 - val_mae: 0.0432
# Epoch 29/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0167 - mae: 0.0349 - val_loss: 0.0013 - val_mae: 0.0295
# Epoch 30/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0166 - mae: 0.0376 - val_loss: 0.0013 - val_mae: 0.0287
# Epoch 31/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0168 - mae: 0.0399 - val_loss: 0.0017 - val_mae: 0.0313
# Epoch 32/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0168 - mae: 0.0404 - val_loss: 0.0021 - val_mae: 0.0380
# Epoch 33/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0168 - mae: 0.0414 - val_loss: 0.0017 - val_mae: 0.0337
# Epoch 34/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0171 - mae: 0.0425 - val_loss: 0.0060 - val_mae: 0.0721
# Epoch 35/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0167 - mae: 0.0427 - val_loss: 0.0041 - val_mae: 0.0542
# Epoch 36/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0165 - mae: 0.0400 - val_loss: 0.0028 - val_mae: 0.0452
# Epoch 37/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0161 - mae: 0.0365 - val_loss: 0.0016 - val_mae: 0.0306
# Epoch 38/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0163 - mae: 0.0385 - val_loss: 0.0100 - val_mae: 0.0971
# Epoch 39/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0163 - mae: 0.0418 - val_loss: 0.0029 - val_mae: 0.0446
# Epoch 40/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0160 - mae: 0.0366 - val_loss: 0.0078 - val_mae: 0.0778
# Epoch 41/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0164 - mae: 0.0425 - val_loss: 0.0013 - val_mae: 0.0288
# Epoch 42/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0159 - mae: 0.0386 - val_loss: 0.0080 - val_mae: 0.0838
# Epoch 43/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0163 - mae: 0.0425 - val_loss: 0.0019 - val_mae: 0.0330
# Epoch 44/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0159 - mae: 0.0374 - val_loss: 0.0014 - val_mae: 0.0275
# Epoch 45/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0157 - mae: 0.0372 - val_loss: 0.0012 - val_mae: 0.0270
# Epoch 46/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0157 - mae: 0.0369 - val_loss: 0.0040 - val_mae: 0.0585
# Epoch 47/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0158 - mae: 0.0390 - val_loss: 0.0017 - val_mae: 0.0293
# Epoch 48/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0154 - mae: 0.0346 - val_loss: 0.0024 - val_mae: 0.0379
# Epoch 49/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0155 - mae: 0.0389 - val_loss: 0.0017 - val_mae: 0.0338
# Epoch 50/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0154 - mae: 0.0381 - val_loss: 0.0025 - val_mae: 0.0389
# Epoch 51/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0157 - mae: 0.0403 - val_loss: 0.0022 - val_mae: 0.0401
# Epoch 52/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0153 - mae: 0.0338 - val_loss: 9.4853e-04 - val_mae: 0.0220
# Epoch 53/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0151 - mae: 0.0360 - val_loss: 0.0011 - val_mae: 0.0234
# Epoch 54/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0152 - mae: 0.0354 - val_loss: 0.0013 - val_mae: 0.0220
# Epoch 55/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0149 - mae: 0.0339 - val_loss: 0.0035 - val_mae: 0.0543
# Epoch 56/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0150 - mae: 0.0359 - val_loss: 0.0033 - val_mae: 0.0473
# Epoch 57/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0153 - mae: 0.0406 - val_loss: 0.0026 - val_mae: 0.0464
# Epoch 58/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0156 - mae: 0.0443 - val_loss: 0.0024 - val_mae: 0.0444
# Epoch 59/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0152 - mae: 0.0412 - val_loss: 0.0067 - val_mae: 0.0785
# Epoch 60/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0147 - mae: 0.0346 - val_loss: 0.0019 - val_mae: 0.0396
# Epoch 61/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0152 - mae: 0.0417 - val_loss: 0.0034 - val_mae: 0.0524
# Epoch 62/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0150 - mae: 0.0414 - val_loss: 0.0021 - val_mae: 0.0414
# Epoch 63/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0150 - mae: 0.0397 - val_loss: 9.4672e-04 - val_mae: 0.0186
# Epoch 64/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0148 - mae: 0.0382 - val_loss: 0.0117 - val_mae: 0.1043
# Epoch 65/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0145 - mae: 0.0367 - val_loss: 0.0028 - val_mae: 0.0472
# Epoch 66/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0144 - mae: 0.0363 - val_loss: 0.0018 - val_mae: 0.0298
# Epoch 67/100
# 89/89 [==============================] - 1s 9ms/step - loss: 0.0143 - mae: 0.0343 - val_loss: 0.0013 - val_mae: 0.0233
# Epoch 68/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0329 - val_loss: 0.0035 - val_mae: 0.0538
# Epoch 69/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0347 - val_loss: 0.0029 - val_mae: 0.0495
# Epoch 70/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0146 - mae: 0.0375 - val_loss: 0.0011 - val_mae: 0.0230
# Epoch 71/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0141 - mae: 0.0345 - val_loss: 0.0012 - val_mae: 0.0272
# Epoch 72/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0374 - val_loss: 0.0026 - val_mae: 0.0333
# Epoch 73/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0339 - val_loss: 0.0016 - val_mae: 0.0274
# Epoch 74/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0139 - mae: 0.0327 - val_loss: 9.4265e-04 - val_mae: 0.0231
# Epoch 75/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0386 - val_loss: 0.0016 - val_mae: 0.0351
# Epoch 76/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0143 - mae: 0.0377 - val_loss: 0.0014 - val_mae: 0.0254
# Epoch 77/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0142 - mae: 0.0380 - val_loss: 0.0021 - val_mae: 0.0336
# Epoch 78/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0137 - mae: 0.0308 - val_loss: 0.0018 - val_mae: 0.0286
# Epoch 79/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0139 - mae: 0.0344 - val_loss: 0.0013 - val_mae: 0.0253
# Epoch 80/100
# 89/89 [==============================] - 1s 7ms/step - loss: 0.0142 - mae: 0.0373 - val_loss: 0.0013 - val_mae: 0.0265
# Epoch 81/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0137 - mae: 0.0324 - val_loss: 0.0033 - val_mae: 0.0400
# Epoch 82/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0140 - mae: 0.0353 - val_loss: 9.9924e-04 - val_mae: 0.0226
# Epoch 83/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0140 - mae: 0.0368 - val_loss: 0.0048 - val_mae: 0.0564
# Epoch 84/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0140 - mae: 0.0346 - val_loss: 0.0130 - val_mae: 0.1103
# Epoch 85/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0138 - mae: 0.0372 - val_loss: 0.0036 - val_mae: 0.0548
# Epoch 86/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0139 - mae: 0.0361 - val_loss: 0.0013 - val_mae: 0.0263
# Epoch 87/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0138 - mae: 0.0342 - val_loss: 0.0014 - val_mae: 0.0261
# Epoch 88/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0137 - mae: 0.0349 - val_loss: 0.0016 - val_mae: 0.0284
# Epoch 89/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0136 - mae: 0.0335 - val_loss: 0.0012 - val_mae: 0.0261
# Epoch 90/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0141 - mae: 0.0355 - val_loss: 0.0055 - val_mae: 0.0659
# Epoch 91/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0134 - mae: 0.0304 - val_loss: 0.0034 - val_mae: 0.0477
# Epoch 92/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0135 - mae: 0.0316 - val_loss: 0.0027 - val_mae: 0.0402
# Epoch 93/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0138 - mae: 0.0371 - val_loss: 0.0026 - val_mae: 0.0405
# Epoch 94/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0137 - mae: 0.0345 - val_loss: 0.0021 - val_mae: 0.0391
# Epoch 95/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0136 - mae: 0.0331 - val_loss: 0.0016 - val_mae: 0.0334
# Epoch 96/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0136 - mae: 0.0347 - val_loss: 0.0046 - val_mae: 0.0601
# Epoch 97/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0139 - mae: 0.0380 - val_loss: 0.0016 - val_mae: 0.0334
# Epoch 98/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0137 - mae: 0.0346 - val_loss: 0.0018 - val_mae: 0.0340
# Epoch 99/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0136 - mae: 0.0327 - val_loss: 0.0024 - val_mae: 0.0416
# Epoch 100/100
# 89/89 [==============================] - 1s 8ms/step - loss: 0.0136 - mae: 0.0338 - val_loss: 0.0020 - val_mae: 0.0355

# %%
# plt.figure(figsize=(9,5))
# plt.plot(GRU_df['loss'], label ='Training loss (MSE)', color = 'blue')
# plt.plot(GRU_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
# plt.xlabel('Mini-batch', fontsize=13)
# plt.ylabel('Loss', fontsize=13)
# plt.legend(fontsize=13)
# plt.savefig('images/GRU_error1.eps', format='eps', dpi=1000)
# plt.show()

# %%
np.random.seed(123)
history_4 = MLP_Model.fit(xtrain, ytrain,epochs=50,validation_data=(xvalid, yvalid))
MLP_df =pd.DataFrame(history_4.history)
MLP_df.tail()
# Out:
# Epoch 1/50
# 89/89 [==============================] - 1s 4ms/step - loss: 1.1057 - mae: 0.6409 - val_loss: 0.0188 - val_mae: 0.1112
# Epoch 2/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0151 - mae: 0.0604 - val_loss: 0.0308 - val_mae: 0.1690
# Epoch 3/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0133 - mae: 0.0505 - val_loss: 0.0076 - val_mae: 0.0798
# Epoch 4/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0114 - mae: 0.0379 - val_loss: 0.0032 - val_mae: 0.0487
# Epoch 5/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0103 - mae: 0.0296 - val_loss: 8.4232e-04 - val_mae: 0.0229
# Epoch 6/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0096 - mae: 0.0241 - val_loss: 5.5656e-04 - val_mae: 0.0198
# Epoch 7/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0092 - mae: 0.0217 - val_loss: 2.8454e-04 - val_mae: 0.0131
# Epoch 8/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0091 - mae: 0.0200 - val_loss: 0.0014 - val_mae: 0.0359
# Epoch 9/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0090 - mae: 0.0219 - val_loss: 2.7663e-04 - val_mae: 0.0128
# Epoch 10/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0088 - mae: 0.0203 - val_loss: 4.9503e-04 - val_mae: 0.0189
# Epoch 11/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0087 - mae: 0.0193 - val_loss: 1.8708e-04 - val_mae: 0.0084
# Epoch 12/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0086 - mae: 0.0193 - val_loss: 5.3387e-04 - val_mae: 0.0204
# Epoch 13/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0086 - mae: 0.0198 - val_loss: 4.7403e-04 - val_mae: 0.0189
# Epoch 14/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0086 - mae: 0.0208 - val_loss: 8.1140e-04 - val_mae: 0.0261
# Epoch 15/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0086 - mae: 0.0196 - val_loss: 6.9861e-04 - val_mae: 0.0239
# Epoch 16/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0085 - mae: 0.0234 - val_loss: 3.3122e-04 - val_mae: 0.0149
# Epoch 17/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0086 - mae: 0.0210 - val_loss: 0.0021 - val_mae: 0.0402
# Epoch 18/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0084 - mae: 0.0187 - val_loss: 0.0023 - val_mae: 0.0466
# Epoch 19/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0084 - mae: 0.0212 - val_loss: 0.0023 - val_mae: 0.0450
# Epoch 20/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0204 - val_loss: 3.0733e-04 - val_mae: 0.0135
# Epoch 21/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0195 - val_loss: 5.8295e-04 - val_mae: 0.0221
# Epoch 22/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0182 - val_loss: 4.2214e-04 - val_mae: 0.0182
# Epoch 23/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0086 - mae: 0.0245 - val_loss: 1.3036e-04 - val_mae: 0.0066
# Epoch 24/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0082 - mae: 0.0197 - val_loss: 1.7161e-04 - val_mae: 0.0093
# Epoch 25/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0199 - val_loss: 8.8568e-04 - val_mae: 0.0276
# Epoch 26/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0204 - val_loss: 3.7494e-04 - val_mae: 0.0171
# Epoch 27/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0197 - val_loss: 0.0012 - val_mae: 0.0340
# Epoch 28/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0084 - mae: 0.0228 - val_loss: 8.4657e-04 - val_mae: 0.0249
# Epoch 29/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0085 - mae: 0.0230 - val_loss: 6.1037e-04 - val_mae: 0.0225
# Epoch 30/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0223 - val_loss: 0.0029 - val_mae: 0.0507
# Epoch 31/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0084 - mae: 0.0207 - val_loss: 0.0054 - val_mae: 0.0701
# Epoch 32/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0193 - val_loss: 1.2275e-04 - val_mae: 0.0065
# Epoch 33/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0197 - val_loss: 4.4490e-04 - val_mae: 0.0186
# Epoch 34/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0085 - mae: 0.0226 - val_loss: 2.0766e-04 - val_mae: 0.0102
# Epoch 35/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0197 - val_loss: 4.2560e-04 - val_mae: 0.0183
# Epoch 36/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0211 - val_loss: 4.7419e-04 - val_mae: 0.0188
# Epoch 37/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0082 - mae: 0.0207 - val_loss: 7.5340e-04 - val_mae: 0.0247
# Epoch 38/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0202 - val_loss: 4.4668e-04 - val_mae: 0.0185
# Epoch 39/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0083 - mae: 0.0198 - val_loss: 6.9449e-04 - val_mae: 0.0229
# Epoch 40/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0081 - mae: 0.0185 - val_loss: 7.7186e-04 - val_mae: 0.0259
# Epoch 41/50
# 89/89 [==============================] - 0s 2ms/step - loss: 0.0084 - mae: 0.0199 - val_loss: 1.7419e-04 - val_mae: 0.0085
# Epoch 42/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0231 - val_loss: 0.0017 - val_mae: 0.0397
# Epoch 43/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0208 - val_loss: 2.4689e-04 - val_mae: 0.0126
# Epoch 44/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0220 - val_loss: 0.0013 - val_mae: 0.0332
# Epoch 45/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0206 - val_loss: 5.7165e-04 - val_mae: 0.0220
# Epoch 46/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0084 - mae: 0.0232 - val_loss: 1.6393e-04 - val_mae: 0.0087
# Epoch 47/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0084 - mae: 0.0215 - val_loss: 1.8393e-04 - val_mae: 0.0090
# Epoch 48/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0080 - mae: 0.0175 - val_loss: 0.0058 - val_mae: 0.0753
# Epoch 49/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0083 - mae: 0.0211 - val_loss: 8.2173e-04 - val_mae: 0.0263
# Epoch 50/50
# 89/89 [==============================] - 0s 3ms/step - loss: 0.0082 - mae: 0.0215 - val_loss: 0.0026 - val_mae: 0.0458

# %%
# plt.figure(figsize=(9,5))
# plt.plot(MLP_df['loss'], label ='Training loss (MSE)', color = 'blue')
# plt.plot(MLP_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
# plt.xlabel('Mini-batch', fontsize=13)
# plt.ylabel('Loss', fontsize=13)
# plt.legend(fontsize=13)
# plt.savefig('images/MLP_Model.eps', format='eps', dpi=1000)
# plt.show()

# %%
np.random.seed(1)
history_5 = conv1D_Model.fit(xtrain,ytrain,batch_size=300,epochs=100,validation_data=(xvalid,yvalid), verbose = 1)
conv1D_df = pd.DataFrame(history_5.history)
conv1D_df.tail()
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 23ms/step - loss: 2.7190 - mae: 1.4951 - val_loss: 9.1595 - val_mae: 2.9435
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0584 - mae: 1.2658 - val_loss: 6.8165 - val_mae: 2.4417
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4372 - mae: 0.9891 - val_loss: 4.1698 - val_mae: 1.7790
# Epoch 4/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.7187 - mae: 0.6259 - val_loss: 1.6900 - val_mae: 1.0095
# Epoch 5/100
# 10/10 [==============================] - 0s 12ms/step - loss: 0.2357 - mae: 0.3057 - val_loss: 0.3673 - val_mae: 0.4127
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0586 - mae: 0.1715 - val_loss: 0.0334 - val_mae: 0.1540
# Epoch 7/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0374 - mae: 0.1493 - val_loss: 0.0033 - val_mae: 0.0486
# Epoch 8/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0259 - mae: 0.0996 - val_loss: 0.0348 - val_mae: 0.1750
# Epoch 9/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0218 - mae: 0.0783 - val_loss: 0.0513 - val_mae: 0.2207
# Epoch 10/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0204 - mae: 0.0729 - val_loss: 0.0380 - val_mae: 0.1787
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0195 - mae: 0.0745 - val_loss: 0.0272 - val_mae: 0.1534
# Epoch 12/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0191 - mae: 0.0754 - val_loss: 0.0231 - val_mae: 0.1445
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0187 - mae: 0.0738 - val_loss: 0.0247 - val_mae: 0.1505
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0184 - mae: 0.0712 - val_loss: 0.0268 - val_mae: 0.1569
# Epoch 15/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0181 - mae: 0.0698 - val_loss: 0.0238 - val_mae: 0.1467
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0177 - mae: 0.0689 - val_loss: 0.0229 - val_mae: 0.1443
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0174 - mae: 0.0681 - val_loss: 0.0210 - val_mae: 0.1382
# Epoch 18/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0171 - mae: 0.0669 - val_loss: 0.0209 - val_mae: 0.1384
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0167 - mae: 0.0655 - val_loss: 0.0194 - val_mae: 0.1332
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0164 - mae: 0.0642 - val_loss: 0.0190 - val_mae: 0.1322
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0160 - mae: 0.0629 - val_loss: 0.0176 - val_mae: 0.1273
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0156 - mae: 0.0609 - val_loss: 0.0168 - val_mae: 0.1251
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0152 - mae: 0.0592 - val_loss: 0.0141 - val_mae: 0.1139
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0147 - mae: 0.0563 - val_loss: 0.0138 - val_mae: 0.1131
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0141 - mae: 0.0529 - val_loss: 0.0115 - val_mae: 0.1015
# Epoch 26/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0135 - mae: 0.0494 - val_loss: 0.0093 - val_mae: 0.0913
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0130 - mae: 0.0446 - val_loss: 0.0075 - val_mae: 0.0789
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0125 - mae: 0.0398 - val_loss: 0.0056 - val_mae: 0.0639
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0119 - mae: 0.0360 - val_loss: 0.0045 - val_mae: 0.0608
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0115 - mae: 0.0312 - val_loss: 0.0034 - val_mae: 0.0443
# Epoch 31/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - mae: 0.0279 - val_loss: 0.0021 - val_mae: 0.0347
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mae: 0.0259 - val_loss: 0.0016 - val_mae: 0.0297
# Epoch 33/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0245 - val_loss: 0.0013 - val_mae: 0.0262
# Epoch 34/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0229 - val_loss: 0.0011 - val_mae: 0.0252
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0223 - val_loss: 7.5100e-04 - val_mae: 0.0192
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0217 - val_loss: 6.2325e-04 - val_mae: 0.0182
# Epoch 37/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0207 - val_loss: 4.7607e-04 - val_mae: 0.0153
# Epoch 38/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0099 - mae: 0.0202 - val_loss: 4.7647e-04 - val_mae: 0.0172
# Epoch 39/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0195 - val_loss: 3.3636e-04 - val_mae: 0.0125
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0188 - val_loss: 3.0072e-04 - val_mae: 0.0109
# Epoch 41/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0097 - mae: 0.0197 - val_loss: 3.0376e-04 - val_mae: 0.0121
# Epoch 42/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0096 - mae: 0.0186 - val_loss: 2.4508e-04 - val_mae: 0.0092
# Epoch 43/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0096 - mae: 0.0185 - val_loss: 2.4378e-04 - val_mae: 0.0099
# Epoch 44/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0095 - mae: 0.0190 - val_loss: 3.1122e-04 - val_mae: 0.0128
# Epoch 45/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0095 - mae: 0.0188 - val_loss: 3.0655e-04 - val_mae: 0.0126
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0095 - mae: 0.0189 - val_loss: 2.0475e-04 - val_mae: 0.0077
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0094 - mae: 0.0175 - val_loss: 2.4642e-04 - val_mae: 0.0101
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0094 - mae: 0.0171 - val_loss: 2.2979e-04 - val_mae: 0.0094
# Epoch 49/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0094 - mae: 0.0219 - val_loss: 5.0038e-04 - val_mae: 0.0179
# Epoch 50/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0093 - mae: 0.0202 - val_loss: 2.5703e-04 - val_mae: 0.0105
# Epoch 51/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0093 - mae: 0.0170 - val_loss: 1.9189e-04 - val_mae: 0.0067
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0093 - mae: 0.0177 - val_loss: 2.2537e-04 - val_mae: 0.0091
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0092 - mae: 0.0187 - val_loss: 2.3019e-04 - val_mae: 0.0094
# Epoch 54/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0092 - mae: 0.0178 - val_loss: 2.0739e-04 - val_mae: 0.0079
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0092 - mae: 0.0172 - val_loss: 1.9112e-04 - val_mae: 0.0067
# Epoch 56/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0092 - mae: 0.0174 - val_loss: 1.8923e-04 - val_mae: 0.0065
# Epoch 57/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0091 - mae: 0.0181 - val_loss: 2.3387e-04 - val_mae: 0.0096
# Epoch 58/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - mae: 0.0185 - val_loss: 3.6209e-04 - val_mae: 0.0147
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0091 - mae: 0.0175 - val_loss: 1.9029e-04 - val_mae: 0.0069
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - mae: 0.0173 - val_loss: 2.1052e-04 - val_mae: 0.0084
# Epoch 61/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mae: 0.0173 - val_loss: 2.3143e-04 - val_mae: 0.0096
# Epoch 62/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mae: 0.0177 - val_loss: 1.9976e-04 - val_mae: 0.0076
# Epoch 63/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mae: 0.0164 - val_loss: 1.9219e-04 - val_mae: 0.0071
# Epoch 64/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0090 - mae: 0.0190 - val_loss: 2.9760e-04 - val_mae: 0.0125
# Epoch 65/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0090 - mae: 0.0169 - val_loss: 3.8236e-04 - val_mae: 0.0159
# Epoch 66/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0091 - mae: 0.0219 - val_loss: 4.6255e-04 - val_mae: 0.0178
# Epoch 67/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0089 - mae: 0.0181 - val_loss: 2.2795e-04 - val_mae: 0.0097
# Epoch 68/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0090 - mae: 0.0175 - val_loss: 2.0511e-04 - val_mae: 0.0082
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - mae: 0.0185 - val_loss: 2.6036e-04 - val_mae: 0.0112
# Epoch 70/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0089 - mae: 0.0177 - val_loss: 2.1371e-04 - val_mae: 0.0087
# Epoch 71/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - mae: 0.0162 - val_loss: 2.1379e-04 - val_mae: 0.0085
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - mae: 0.0195 - val_loss: 3.5331e-04 - val_mae: 0.0146
# Epoch 73/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0089 - mae: 0.0165 - val_loss: 1.9104e-04 - val_mae: 0.0072
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - mae: 0.0188 - val_loss: 2.9716e-04 - val_mae: 0.0128
# Epoch 75/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0180 - val_loss: 1.9562e-04 - val_mae: 0.0077
# Epoch 76/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0162 - val_loss: 2.5153e-04 - val_mae: 0.0108
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0088 - mae: 0.0183 - val_loss: 2.7407e-04 - val_mae: 0.0118
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0088 - mae: 0.0165 - val_loss: 1.8545e-04 - val_mae: 0.0070
# Epoch 79/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0170 - val_loss: 2.6170e-04 - val_mae: 0.0114
# Epoch 80/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0179 - val_loss: 2.0424e-04 - val_mae: 0.0084
# Epoch 81/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0161 - val_loss: 1.8481e-04 - val_mae: 0.0069
# Epoch 82/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0088 - mae: 0.0167 - val_loss: 2.2631e-04 - val_mae: 0.0097
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - mae: 0.0163 - val_loss: 2.0909e-04 - val_mae: 0.0087
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0087 - mae: 0.0171 - val_loss: 2.2271e-04 - val_mae: 0.0095
# Epoch 85/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - mae: 0.0160 - val_loss: 2.4754e-04 - val_mae: 0.0107
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0087 - mae: 0.0160 - val_loss: 1.7898e-04 - val_mae: 0.0064
# Epoch 87/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0087 - mae: 0.0166 - val_loss: 1.8959e-04 - val_mae: 0.0075
# Epoch 88/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0087 - mae: 0.0174 - val_loss: 2.4817e-04 - val_mae: 0.0109
# Epoch 89/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0087 - mae: 0.0165 - val_loss: 2.1928e-04 - val_mae: 0.0094
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - mae: 0.0165 - val_loss: 1.8046e-04 - val_mae: 0.0067
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0087 - mae: 0.0171 - val_loss: 1.9887e-04 - val_mae: 0.0082
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0087 - mae: 0.0184 - val_loss: 2.5489e-04 - val_mae: 0.0112
# Epoch 93/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0087 - mae: 0.0165 - val_loss: 1.8915e-04 - val_mae: 0.0075
# Epoch 94/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0087 - mae: 0.0163 - val_loss: 1.7892e-04 - val_mae: 0.0067
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mae: 0.0164 - val_loss: 2.1258e-04 - val_mae: 0.0090
# Epoch 96/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0086 - mae: 0.0166 - val_loss: 2.4141e-04 - val_mae: 0.0106
# Epoch 97/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mae: 0.0160 - val_loss: 2.1005e-04 - val_mae: 0.0088
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mae: 0.0164 - val_loss: 2.7371e-04 - val_mae: 0.0120
# Epoch 99/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mae: 0.0160 - val_loss: 1.8388e-04 - val_mae: 0.0072
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mae: 0.0165 - val_loss: 2.3478e-04 - val_mae: 0.0102

# %%
# print('')
# plt.figure(figsize=(9,5))
# plt.plot(conv1D_df['loss'], label ='Training loss (MSE)', color = 'blue')
# plt.plot(conv1D_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
# plt.xlabel('Mini-batch', fontsize=13)
# plt.ylabel('Loss', fontsize=13)
# plt.legend(fontsize=13)
# plt.savefig('images/conv1D_Model.eps', format='eps', dpi=1000)
# plt.show()

# %% [markdown]
# ## Predictions
# Now we will use our model to make predictions.

# %%
real_pred1 = RNN.predict(xtest)
real_pred2 = LSTM_Model.predict(xtest)
real_pred3 = GRU_Model.predict(xtest)
real_pred4 = MLP_Model.predict(xtest)
real_pred5 = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 3ms/step
# 30/30 [==============================] - 1s 4ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step

# %%
real_pred1.shape,real_pred2.shape,real_pred3.shape,real_pred4.shape,real_pred5.shape
# Out:
# ((949, 5, 1), (949, 5, 1), (949, 5, 1), (949, 5), (949, 5, 1))

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': real_pred1[:,0].flatten(),
    'LSTM': real_pred2[:,0].flatten(),
    'GRU': real_pred3[:,0].flatten(),
    'MLP': real_pred4[:,0].flatten(),  
    'conv1D': real_pred5[:,0].flatten(),  
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  4.421658  4.388435  4.493723  4.424933  4.428780       4.4179
# 1  4.421657  4.388525  4.494528  4.424921  4.428984       4.4187
# 2  4.421658  4.388568  4.495131  4.424894  4.429085       4.4193
# 3  4.422858  4.389661  4.495131  4.425648  4.429400       4.4193
# 4  4.425560  4.391988  4.495131  4.427508  4.430480       4.4193

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(19,10))

axs[0,0].plot(RNN_df['loss'], label ='Training ', color = 'blue')
axs[0,0].plot(RNN_df['val_loss'], label='Validation ', color = 'orange')
axs[0,0].set_title('RNN (Loss / Mean Square Error)')

axs[0,1].plot(LSTM_df['loss'], label ='Training loss (MSE)', color = 'blue')
axs[0,1].plot(LSTM_df['val_loss'], label='Validation loss (MSE)', color = 'orange')
axs[0,1].set_title('LSTM (Loss / Mean Square Error)')

axs[0,2].plot(GRU_df['loss'], label ='Training ', color = 'blue')
axs[0,2].plot(GRU_df['val_loss'], label='Validation ', color = 'orange')
axs[0,2].set_title('GRU (Loss / Mean Square Error)')

axs[1,0].plot(MLP_df['loss'], label ='Training ', color = 'blue')
axs[1,0].plot(MLP_df['val_loss'], label='Validation ', color = 'orange')
axs[1,0].set_title('MLP (Loss / Mean Square Error)')

axs[1,1].plot(conv1D_df['loss'], label ='Training', color = 'blue')
axs[1,1].plot(conv1D_df['val_loss'], label='Validation ', color = 'orange')
axs[1,1].set_title('conv1D (Loss / Mean Square Error)')

axs[1,2].set_title('Loss Function')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')
#Add legend to all plots
axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Epochs', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('Loss', fontsize=13)
    


    
plt.tight_layout()
plt.savefig('images/Combined3.png', format='png', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Combined Plots

# %%
plt.figure(figsize=(19,8))
plt.plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
plt.plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
plt.plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
plt.plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
plt.plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
plt.plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')
plt.xlabel('Time (days)', fontsize=13)
plt.ylabel('Loss', fontsize=13)
plt.legend(fontsize=13)
plt.savefig('images/Combined1.eps', format='eps', dpi=1000)
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15,8))

axs[0,0].plot(Pred_Data['RNN'], color='red', label='RNN')
axs[0,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,0].set_title('RNN vs Actual Rate')

axs[0,1].plot(Pred_Data['LSTM'], color='green', label='LSTM')
axs[0,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,1].set_title('LSTM vs Actual Rate')

axs[0,2].plot(Pred_Data['GRU'], color='orange', label='GRU')
axs[0,2].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[0,2].set_title('GRU vs Actual Rate')

axs[1,0].plot(Pred_Data['MLP'], color='maroon', label='MLP')
axs[1,0].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,0].set_title('MLP vs Actual Rate')

axs[1,1].plot(Pred_Data['conv1D'], color='navy', label='conv1D')
axs[1,1].plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
axs[1,1].set_title('conv1D vs Actual Rate')

axs[1,2].plot(Pred_Data['RNN'], color = 'red', label = 'RNN')
axs[1,2].plot(Pred_Data['LSTM'], color = 'green', label = 'LSTM')
axs[1,2].plot(Pred_Data['GRU'], color = 'orange', label = 'GRU')
axs[1,2].plot(Pred_Data['MLP'], color = 'maroon', label = 'MLP')
axs[1,2].plot(Pred_Data['conv1D'], color = 'black', label = 'conv1D')
axs[1,2].plot(xtest[:,0,0].flatten(), color = 'blue', label = 'Actual Rate')

axs[1,2].set_title('Combined Plots')
# Add a blank subplot to fill the last space in the grid
axs[1,2].axis('off')

axs[0,0].legend(loc='upper left')
axs[0,1].legend(loc='upper left')
axs[0,2].legend(loc='upper left')
axs[1,0].legend(loc='upper left')
axs[1,1].legend(loc='upper left')
axs[1,2].legend(loc='upper left')
# Add a shared x-axis label to the bottom row of subplots
for ax in axs[1,:]:
    ax.set_xlabel('Time (days)', fontsize=13)

# Add a shared y-axis label to the left column of subplots
for ax in axs[:,0]:
    ax.set_ylabel('GHS/USD Rates', fontsize=13)
    

plt.tight_layout()
plt.savefig('images/Combined2.png', format='png', dpi=1000)
plt.show()

# %%
# plt.figure(figsize=(19,8))
# plt.plot(Pred_Data['RNN'], color='red', label='RNN')
# plt.plot(xtest[:,0,0].flatten(), color='blue', label='Actual Rate')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Exchange Rate', fontsize=13)
# plt.title('RNN vs Actual Rate', fontsize=13)
# plt.legend(fontsize=13,loc='upper left', ncol=2)
# plt.show()

# %%
# Assuming xtest is the test data and has shape (num_samples, num_timesteps, num_features)
rnn_pred = RNN.predict(xtest)
lstm_pred = LSTM_Model.predict(xtest)
gru_pred = GRU_Model.predict(xtest)
mlp_pred = MLP_Model.predict(xtest)
conv1d_pred = conv1D_Model.predict(xtest)
# Out:
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 4ms/step
# 30/30 [==============================] - 0s 3ms/step
# 30/30 [==============================] - 0s 2ms/step
# 30/30 [==============================] - 0s 2ms/step

# %%
# Combined Models
Pred_Data = pd.DataFrame({
    'RNN': rnn_pred[:,0].flatten(),
    'LSTM': lstm_pred[:,0].flatten(),
    'GRU': gru_pred[:,0].flatten(),
    'MLP': mlp_pred[:,0].flatten(),  # fixed typo here
    'conv1D': conv1d_pred[:,0].flatten(),  # fixed typo here
    'Actual Rate': xtest[:,0].flatten()
})

Pred_Data.head()
# Out:
#         RNN      LSTM       GRU       MLP    conv1D  Actual Rate
# 0  4.421658  4.388435  4.493723  4.424933  4.428780       4.4179
# 1  4.421657  4.388525  4.494528  4.424921  4.428984       4.4187
# 2  4.421658  4.388568  4.495131  4.424894  4.429085       4.4193
# 3  4.422858  4.389661  4.495131  4.425648  4.429400       4.4193
# 4  4.425560  4.391988  4.495131  4.427508  4.430480       4.4193

# %%
actuals = ytest.reshape(-1, 1)
actuals.shape,Pred_Data.shape
# Out:
# ((949, 1), (949, 6))

# %%
# print('')
# plt.figure(figsize=(10,5))
# plt.plot(actuals, label="Actual Rate", color = 'blue')
# plt.plot(Pred_Data['RNN'], label="RNN", color = 'red')
# plt.xlabel('Time (days)', fontsize=13)
# plt.ylabel('Rate', fontsize=13)
# plt.legend(fontsize=13)
# plt.show()

# %%
print('The the mean absolute error committed by the standard RNN model is: ', mean_absolute_error(actuals,Pred_Data['RNN']))
# Out:
# The the mean absolute error committed by the standard RNN model is:  0.005053631215552759

# %%
# Evaluate RNN predictions
rnn_mae = mean_absolute_error(ytest, Pred_Data['RNN'])
rnn_mse = mean_squared_error(ytest, Pred_Data['RNN'])
rnn_rmse = np.sqrt(rnn_mse)
rnn_r2 = r2_score(ytest, Pred_Data['RNN'])

# Evaluate LSTM predictions
lstm_mae = mean_absolute_error(ytest, Pred_Data['LSTM'])
lstm_mse = mean_squared_error(ytest, Pred_Data['LSTM'])
lstm_rmse = np.sqrt(lstm_mse)
lstm_r2 = r2_score(ytest, Pred_Data['LSTM'])

# Evaluate GRU predictions
gru_mae = mean_absolute_error(ytest, Pred_Data['GRU'])
gru_mse = mean_squared_error(ytest, Pred_Data['GRU'])
gru_rmse = np.sqrt(gru_mse)
gru_r2 = r2_score(ytest, Pred_Data['GRU'])

# Evaluate MLP predictions
mlp_mae = mean_absolute_error(ytest, Pred_Data['MLP'])
mlp_mse = mean_squared_error(ytest, Pred_Data['MLP'])
mlp_rmse = np.sqrt(mlp_mse)
mlp_r2 = r2_score(ytest, Pred_Data['MLP'])

# Evaluate Conv1D predictions
conv1d_mae = mean_absolute_error(ytest, Pred_Data['conv1D'])
conv1d_mse = mean_squared_error(ytest, Pred_Data['conv1D'])
conv1d_rmse = np.sqrt(conv1d_mse)
conv1d_r2 = r2_score(ytest, Pred_Data['conv1D'])

# %%
print("RNN Evaluation Metrics:")
print(f"MAE: {rnn_mae:.4f}, MSE: {rnn_mse:.4f}, RMSE: {rnn_rmse:.4f}, R2: {rnn_r2:.4f}\n")

print("LSTM Evaluation Metrics:")
print(f"MAE: {lstm_mae:.4f}, MSE: {lstm_mse:.4f}, RMSE: {lstm_rmse:.4f}, R2: {lstm_r2:.4f}\n")

print("GRU Evaluation Metrics:")
print(f"MAE: {gru_mae:.4f}, MSE: {gru_mse:.4f}, RMSE: {gru_rmse:.4f}, R2: {gru_r2:.4f}\n")

print("MLP Evaluation Metrics:")
print(f"MAE: {mlp_mae:.4f}, MSE: {mlp_mse:.4f}, RMSE: {mlp_rmse:.4f}, R2: {mlp_r2:.4f}\n")

print("Conv1D Evaluation Metrics:")
print(f"MAE: {conv1d_mae:.4f}, MSE: {conv1d_mse:.4f}, RMSE: {conv1d_rmse:.4f}, R2: {conv1d_r2:.4f}\n")
# Out:
# RNN Evaluation Metrics:
# MAE: 0.0051, MSE: 0.0001, RMSE: 0.0093, R2: 0.9994
#
# LSTM Evaluation Metrics:
# MAE: 0.0890, MSE: 0.0088, RMSE: 0.0937, R2: 0.9363
#
# GRU Evaluation Metrics:
# MAE: 0.0409, MSE: 0.0025, RMSE: 0.0498, R2: 0.9820
#
# MLP Evaluation Metrics:
# MAE: 0.0107, MSE: 0.0003, RMSE: 0.0162, R2: 0.9981
#
# Conv1D Evaluation Metrics:
# MAE: 0.0111, MSE: 0.0003, RMSE: 0.0175, R2: 0.9978

# %%
# Create a DataFrame with evaluation metrics
Results = pd.DataFrame({'MAE': [rnn_mae, lstm_mae, gru_mae, mlp_mae, conv1d_mae],
                        'MSE': [rnn_mse, lstm_mse, gru_mse, mlp_mse, conv1d_mse],
                        'RMSE': [rnn_rmse, lstm_rmse, gru_rmse, mlp_rmse, conv1d_rmse],
                        'R2': [rnn_r2, lstm_r2, gru_r2, mlp_r2, conv1d_r2]},
                       index=['RNN', 'LSTM', 'GRU', 'MLP', 'Conv1D'])
Results
# Out:
#              MAE       MSE      RMSE        R2
# RNN     0.005054  0.000086  0.009298  0.999373
# LSTM    0.088974  0.008782  0.093713  0.936296
# GRU     0.040879  0.002476  0.049763  0.982037
# MLP     0.010663  0.000264  0.016242  0.998087
# Conv1D  0.011088  0.000306  0.017486  0.997782
